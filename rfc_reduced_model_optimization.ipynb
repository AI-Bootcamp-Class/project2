# %% [markdown]
# ## Build Model with Reduced Feature Set

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import balanced_accuracy_score, classification_report
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
# Import scaled earthquake data with reduced feature set
df = pd.read_csv('Resources/earthquake_data_reduced.csv')
display(df.head())
df.info()
# Out:
#    longitude  latitude     depth  magnitude  min_station_distance  \
# 0  -0.858789  0.217395 -0.138401   1.259068             -0.621166
# 1  -1.586411  1.453026  2.957343   0.278647              0.182939
# 2  -0.451425  1.705352  1.297980   0.866900              2.000126
# 3  -0.891745  0.639950 -0.776489   0.808074             -0.566141
# 4   0.049063  0.917870 -0.567035   0.866900              1.537912
#
#    nodal_plane_1_dip  nodal_plane_1_strike  nodal_plane_2_dip  \
# 0           0.764993             -0.187953          -3.275980
# 1          -0.322804             -0.143028           0.718901
# 2          -0.866703             -0.187953          -1.531736
# 3          -0.594754              0.620696           0.775167
# 4          -0.594754              1.564120           0.775167
#
#    nodal_plane_2_rake  nodal_plane_2_strike  ...  t_axis_length  \
# 0            1.009308              1.075972  ...      -0.059860
# 1           -0.131508             -1.479373  ...      -0.066207
# 2           -0.587834              1.217936  ...      -0.062811
# 3           -1.224790              1.132758  ...      -0.062760
# 4           -0.179042              0.309369  ...      -0.062428
#
#    t_axis_plunge  percent_double_couple  scalar_moment  tensor_mpp  \
# 0       3.288087              -0.131701      -0.058242   -0.053888
# 1       0.813702              -0.016844      -0.065891   -0.050703
# 2      -0.542928              -0.045558      -0.062687   -0.048152
# 3      -0.274021              -0.138879      -0.063113   -0.047294
# 4      -0.128764              -0.009665      -0.062141   -0.048454
#
#    tensor_mrp  tensor_mrr  tensor_mrt  tensor_mtt  mmi_class
# 0   -0.019118   -0.003759   -0.020843    0.055255          2
# 1   -0.004675   -0.031174   -0.034918    0.059791          0
# 2    0.025176   -0.045815   -0.028006    0.061360          0
# 3   -0.015576   -0.037577   -0.028875    0.058169          0
# 4    0.008477   -0.034790   -0.019123    0.058550          1
#
# [5 rows x 25 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 957 entries, 0 to 956
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   longitude              957 non-null    float64
#  1   latitude               957 non-null    float64
#  2   depth                  957 non-null    float64
#  3   magnitude              957 non-null    float64
#  4   min_station_distance   957 non-null    float64
#  5   nodal_plane_1_dip      957 non-null    float64
#  6   nodal_plane_1_strike   957 non-null    float64
#  7   nodal_plane_2_dip      957 non-null    float64
#  8   nodal_plane_2_rake     957 non-null    float64
#  9   nodal_plane_2_strike   957 non-null    float64
#  10  n_axis_length          957 non-null    float64
#  11  n_axis_plunge          957 non-null    float64
#  12  p_axis_azimuth         957 non-null    float64
#  13  p_axis_plunge          957 non-null    float64
#  14  t_axis_azimuth         957 non-null    float64
#  15  t_axis_length          957 non-null    float64
#  16  t_axis_plunge          957 non-null    float64
#  17  percent_double_couple  957 non-null    float64
#  18  scalar_moment          957 non-null    float64
#  19  tensor_mpp             957 non-null    float64
#  20  tensor_mrp             957 non-null    float64
#  21  tensor_mrr             957 non-null    float64
#  22  tensor_mrt             957 non-null    float64
#  23  tensor_mtt             957 non-null    float64
#  24  mmi_class              957 non-null    int64
# dtypes: float64(24), int64(1)
# memory usage: 187.0 KB

# %%
# Create X and y
X = df.drop(columns='mmi_class', axis=1)
# y = df['mmi_class'].values.reshape(-1, 1)
y = df['mmi_class']
display(X.head())
display(y[:5])
# Out:
#    longitude  latitude     depth  magnitude  min_station_distance  \
# 0  -0.858789  0.217395 -0.138401   1.259068             -0.621166
# 1  -1.586411  1.453026  2.957343   0.278647              0.182939
# 2  -0.451425  1.705352  1.297980   0.866900              2.000126
# 3  -0.891745  0.639950 -0.776489   0.808074             -0.566141
# 4   0.049063  0.917870 -0.567035   0.866900              1.537912
#
#    nodal_plane_1_dip  nodal_plane_1_strike  nodal_plane_2_dip  \
# 0           0.764993             -0.187953          -3.275980
# 1          -0.322804             -0.143028           0.718901
# 2          -0.866703             -0.187953          -1.531736
# 3          -0.594754              0.620696           0.775167
# 4          -0.594754              1.564120           0.775167
#
#    nodal_plane_2_rake  nodal_plane_2_strike  ...  t_axis_azimuth  \
# 0            1.009308              1.075972  ...       -1.568777
# 1           -0.131508             -1.479373  ...       -0.890918
# 2           -0.587834              1.217936  ...        0.611749
# 3           -1.224790              1.132758  ...       -0.885430
# 4           -0.179042              0.309369  ...        1.247287
#
#    t_axis_length  t_axis_plunge  percent_double_couple  scalar_moment  \
# 0      -0.059860       3.288087              -0.131701      -0.058242
# 1      -0.066207       0.813702              -0.016844      -0.065891
# 2      -0.062811      -0.542928              -0.045558      -0.062687
# 3      -0.062760      -0.274021              -0.138879      -0.063113
# 4      -0.062428      -0.128764              -0.009665      -0.062141
#
#    tensor_mpp  tensor_mrp  tensor_mrr  tensor_mrt  tensor_mtt
# 0   -0.053888   -0.019118   -0.003759   -0.020843    0.055255
# 1   -0.050703   -0.004675   -0.031174   -0.034918    0.059791
# 2   -0.048152    0.025176   -0.045815   -0.028006    0.061360
# 3   -0.047294   -0.015576   -0.037577   -0.028875    0.058169
# 4   -0.048454    0.008477   -0.034790   -0.019123    0.058550
#
# [5 rows x 24 columns]
# 0    2
# 1    0
# 2    0
# 3    0
# 4    1
# Name: mmi_class, dtype: int64

# %%
# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Apply Randomized Search of Best Hyperparameters

# %%
# Define a hyperparameter grid
param_grid = {'n_estimators': range(100, 1000, 10),
              'max_features': ['sqrt', 'log2'],
              'max_depth': range(1, 40, 2),
              'min_samples_split': [2, 3, 4, 5],
              'min_samples_leaf': [1, 2, 4],
              'bootstrap': [True, False]}

# Instantiate a Random Forest Classifier model
rfc = RandomForestClassifier(random_state=0)

# %%
# Instantiate the Randomized Search Estimator
random_rfc = RandomizedSearchCV(rfc, param_grid, random_state=0, verbose=3)

# Fit the Randomized Search Estimator on train data
random_rfc.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END bootstrap=False, max_depth=23, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=580;, score=0.597 total time=   1.4s
# [CV 2/5] END bootstrap=False, max_depth=23, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=580;, score=0.542 total time=   1.2s
# [CV 3/5] END bootstrap=False, max_depth=23, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=580;, score=0.643 total time=   1.4s
# [CV 4/5] END bootstrap=False, max_depth=23, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=580;, score=0.657 total time=   1.2s
# [CV 5/5] END bootstrap=False, max_depth=23, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=580;, score=0.678 total time=   1.2s
# [CV 1/5] END bootstrap=False, max_depth=1, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=170;, score=0.514 total time=   0.1s
# [CV 2/5] END bootstrap=False, max_depth=1, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=170;, score=0.465 total time=   0.1s
# [CV 3/5] END bootstrap=False, max_depth=1, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=170;, score=0.524 total time=   0.1s
# [CV 4/5] END bootstrap=False, max_depth=1, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=170;, score=0.462 total time=   0.1s
# [CV 5/5] END bootstrap=False, max_depth=1, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=170;, score=0.469 total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=39, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=530;, score=0.625 total time=   1.1s
# [CV 2/5] END bootstrap=True, max_depth=39, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=530;, score=0.535 total time=   1.1s
# [CV 3/5] END bootstrap=True, max_depth=39, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=530;, score=0.671 total time=   1.2s
# [CV 4/5] END bootstrap=True, max_depth=39, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=530;, score=0.671 total time=   1.1s
# [CV 5/5] END bootstrap=True, max_depth=39, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=530;, score=0.657 total time=   1.3s
# [CV 1/5] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=910;, score=0.625 total time=   1.1s
# [CV 2/5] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=910;, score=0.535 total time=   1.1s
# [CV 3/5] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=910;, score=0.601 total time=   1.1s
# [CV 4/5] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=910;, score=0.601 total time=   1.1s
# [CV 5/5] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=910;, score=0.587 total time=   1.1s
# [CV 1/5] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=130;, score=0.597 total time=   0.2s
# [CV 2/5] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=130;, score=0.556 total time=   0.2s
# [CV 3/5] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=130;, score=0.622 total time=   0.2s
# [CV 4/5] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=130;, score=0.636 total time=   0.2s
# [CV 5/5] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=130;, score=0.692 total time=   0.2s
# [CV 1/5] END bootstrap=True, max_depth=39, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=630;, score=0.618 total time=   1.3s
# [CV 2/5] END bootstrap=True, max_depth=39, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=630;, score=0.542 total time=   1.3s
# [CV 3/5] END bootstrap=True, max_depth=39, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=630;, score=0.650 total time=   1.3s
# [CV 4/5] END bootstrap=True, max_depth=39, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=630;, score=0.650 total time=   1.2s
# [CV 5/5] END bootstrap=True, max_depth=39, max_features=sqrt, min_samples_leaf=4, min_samples_split=4, n_estimators=630;, score=0.685 total time=   1.3s
# [CV 1/5] END bootstrap=False, max_depth=39, max_features=log2, min_samples_leaf=4, min_samples_split=4, n_estimators=830;, score=0.611 total time=   1.6s
# [CV 2/5] END bootstrap=False, max_depth=39, max_features=log2, min_samples_leaf=4, min_samples_split=4, n_estimators=830;, score=0.556 total time=   1.5s
# [CV 3/5] END bootstrap=False, max_depth=39, max_features=log2, min_samples_leaf=4, min_samples_split=4, n_estimators=830;, score=0.650 total time=   1.7s
# [CV 4/5] END bootstrap=False, max_depth=39, max_features=log2, min_samples_leaf=4, min_samples_split=4, n_estimators=830;, score=0.657 total time=   1.5s
# [CV 5/5] END bootstrap=False, max_depth=39, max_features=log2, min_samples_leaf=4, min_samples_split=4, n_estimators=830;, score=0.671 total time=   1.6s
# [CV 1/5] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=460;, score=0.618 total time=   0.8s
# [CV 2/5] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=460;, score=0.528 total time=   0.8s
# [CV 3/5] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=460;, score=0.643 total time=   0.8s
# [CV 4/5] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=460;, score=0.636 total time=   0.8s
# [CV 5/5] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=460;, score=0.664 total time=   0.8s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.569 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.636 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.685 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.685 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=660;, score=0.611 total time=   1.5s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=660;, score=0.556 total time=   1.3s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=660;, score=0.650 total time=   1.3s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=660;, score=0.657 total time=   1.2s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=660;, score=0.671 total time=   1.2s
# RandomizedSearchCV(estimator=RandomForestClassifier(random_state=0),
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': range(1, 40, 2),
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 3, 4, 5],
#                                         'n_estimators': range(100, 1000, 10)},
#                    random_state=0, verbose=3)

# %%
# Print best hyperparameters
print(random_rfc.best_params_)
# Out:
# {'n_estimators': 210, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 35, 'bootstrap': False}

# %%
# Make predictions with the hypertuned model
random_rfc_train_predict = random_rfc.predict(X_train)
random_rfc_test_predict = random_rfc.predict(X_test)

# Calculate and print the balanced accuracies
print(f"Accuracy - Train: {balanced_accuracy_score(y_train, random_rfc_train_predict):.3f}")
print(f"Accuracy - Test: {balanced_accuracy_score(y_test, random_rfc_test_predict):.3f}")

# Calculate the classification report
print(classification_report(y_test, random_rfc_test_predict))
# Out:
# Accuracy - Train: 1.000
# Accuracy - Test: 0.576
#               precision    recall  f1-score   support
#
#            0       0.65      0.71      0.68        89
#            1       0.43      0.45      0.44        83
#            2       0.68      0.57      0.62        68
#
#     accuracy                           0.58       240
#    macro avg       0.59      0.58      0.58       240
# weighted avg       0.58      0.58      0.58       240

# %% [markdown]
# ### Refine Hyperparameter Set Using Grid Search

# %%
# Define a new hyperparameter grid around the best hyperparameters from before
param_grid = {'n_estimators': range(200, 220),
              'max_features': ['sqrt'],
              'max_depth': range(33, 37),
              'min_samples_split': [4],
              'min_samples_leaf': [2],
              'bootstrap': [False]}

# Instantiate a Random Forest Classifier model
rfc2 = RandomForestClassifier(random_state=0)

# %%
# Use a grid search this time.random_rfc2.random_rfc2
# Instantiate the Grid Search Estimator
grid_rfc2 = GridSearchCV(rfc2, param_grid, verbose=3)

# Fit the Randomized Search Estimator on train data
grid_rfc2.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# [CV 1/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.597 total time=   0.5s
# [CV 2/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.576 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.643 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.685 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.678 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=201;, score=0.597 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=201;, score=0.576 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=201;, score=0.643 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=201;, score=0.685 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=201;, score=0.678 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=202;, score=0.583 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=202;, score=0.569 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=202;, score=0.643 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=202;, score=0.685 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=202;, score=0.692 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=203;, score=0.590 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=203;, score=0.576 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=203;, score=0.636 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=203;, score=0.692 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=203;, score=0.692 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=204;, score=0.590 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=204;, score=0.576 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=204;, score=0.636 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=204;, score=0.692 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=204;, score=0.685 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=205;, score=0.590 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=205;, score=0.576 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=205;, score=0.629 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=205;, score=0.692 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=205;, score=0.692 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=206;, score=0.590 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=206;, score=0.576 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=206;, score=0.629 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=206;, score=0.692 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=206;, score=0.678 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=207;, score=0.590 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=207;, score=0.562 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=207;, score=0.629 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=207;, score=0.685 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=207;, score=0.692 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=208;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=208;, score=0.569 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=208;, score=0.636 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=208;, score=0.692 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=208;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=209;, score=0.590 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=209;, score=0.569 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=209;, score=0.629 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=209;, score=0.685 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=209;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.590 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.569 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.636 total time=   0.5s
# [CV 4/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.685 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.685 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=211;, score=0.590 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=211;, score=0.569 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=211;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=211;, score=0.678 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=211;, score=0.685 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=212;, score=0.590 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=212;, score=0.569 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=212;, score=0.622 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=212;, score=0.671 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=212;, score=0.685 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=213;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=213;, score=0.562 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=213;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=213;, score=0.664 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=213;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=214;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=214;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=214;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=214;, score=0.671 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=214;, score=0.685 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=215;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=215;, score=0.562 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=215;, score=0.622 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=215;, score=0.664 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=215;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=216;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=216;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=216;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=216;, score=0.664 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=216;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=217;, score=0.590 total time=   0.5s
# [CV 2/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=217;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=217;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=217;, score=0.664 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=217;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=218;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=218;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=218;, score=0.629 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=218;, score=0.671 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=218;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=219;, score=0.597 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=219;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=219;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=219;, score=0.664 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=33, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=219;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.597 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.576 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.643 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.685 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.678 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=201;, score=0.597 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=201;, score=0.576 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=201;, score=0.643 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=201;, score=0.685 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=201;, score=0.678 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=202;, score=0.583 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=202;, score=0.569 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=202;, score=0.643 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=202;, score=0.685 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=202;, score=0.692 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=203;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=203;, score=0.576 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=203;, score=0.636 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=203;, score=0.692 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=203;, score=0.692 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=204;, score=0.590 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=204;, score=0.576 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=204;, score=0.636 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=204;, score=0.692 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=204;, score=0.685 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=205;, score=0.590 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=205;, score=0.576 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=205;, score=0.629 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=205;, score=0.692 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=205;, score=0.692 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=206;, score=0.590 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=206;, score=0.576 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=206;, score=0.629 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=206;, score=0.692 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=206;, score=0.678 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=207;, score=0.590 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=207;, score=0.562 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=207;, score=0.629 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=207;, score=0.685 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=207;, score=0.692 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=208;, score=0.590 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=208;, score=0.569 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=208;, score=0.636 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=208;, score=0.692 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=208;, score=0.678 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=209;, score=0.590 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=209;, score=0.569 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=209;, score=0.629 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=209;, score=0.685 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=209;, score=0.678 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.590 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.569 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.636 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.685 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.685 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=211;, score=0.590 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=211;, score=0.569 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=211;, score=0.622 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=211;, score=0.678 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=211;, score=0.685 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=212;, score=0.590 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=212;, score=0.569 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=212;, score=0.622 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=212;, score=0.671 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=212;, score=0.685 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=213;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=213;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=213;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=213;, score=0.664 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=213;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=214;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=214;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=214;, score=0.622 total time=   0.5s
# [CV 4/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=214;, score=0.671 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=214;, score=0.685 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=215;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=215;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=215;, score=0.622 total time=   0.5s
# [CV 4/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=215;, score=0.664 total time=   0.5s
# [CV 5/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=215;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=216;, score=0.590 total time=   0.5s
# [CV 2/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=216;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=216;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=216;, score=0.664 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=216;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=217;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=217;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=217;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=217;, score=0.664 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=217;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=218;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=218;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=218;, score=0.629 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=218;, score=0.671 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=218;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=219;, score=0.597 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=219;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=219;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=219;, score=0.664 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=219;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.597 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.576 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.643 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.685 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=201;, score=0.597 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=201;, score=0.576 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=201;, score=0.643 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=201;, score=0.685 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=201;, score=0.678 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=202;, score=0.583 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=202;, score=0.569 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=202;, score=0.643 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=202;, score=0.685 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=202;, score=0.692 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=203;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=203;, score=0.576 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=203;, score=0.636 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=203;, score=0.692 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=203;, score=0.692 total time=   0.5s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=204;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=204;, score=0.576 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=204;, score=0.636 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=204;, score=0.692 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=204;, score=0.685 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=205;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=205;, score=0.576 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=205;, score=0.629 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=205;, score=0.692 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=205;, score=0.692 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=206;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=206;, score=0.576 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=206;, score=0.629 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=206;, score=0.692 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=206;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=207;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=207;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=207;, score=0.629 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=207;, score=0.685 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=207;, score=0.692 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=208;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=208;, score=0.569 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=208;, score=0.636 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=208;, score=0.692 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=208;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=209;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=209;, score=0.569 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=209;, score=0.629 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=209;, score=0.685 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=209;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.569 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.636 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.685 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.685 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=211;, score=0.590 total time=   0.5s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=211;, score=0.569 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=211;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=211;, score=0.678 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=211;, score=0.685 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=212;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=212;, score=0.569 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=212;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=212;, score=0.671 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=212;, score=0.685 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=213;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=213;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=213;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=213;, score=0.664 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=213;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=214;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=214;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=214;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=214;, score=0.671 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=214;, score=0.685 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=215;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=215;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=215;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=215;, score=0.664 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=215;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=216;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=216;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=216;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=216;, score=0.664 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=216;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=217;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=217;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=217;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=217;, score=0.664 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=217;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=218;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=218;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=218;, score=0.629 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=218;, score=0.671 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=218;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=219;, score=0.597 total time=   0.5s
# [CV 2/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=219;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=219;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=219;, score=0.664 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=219;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.597 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.576 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.643 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.685 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=201;, score=0.597 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=201;, score=0.576 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=201;, score=0.643 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=201;, score=0.685 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=201;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=202;, score=0.583 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=202;, score=0.569 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=202;, score=0.643 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=202;, score=0.685 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=202;, score=0.692 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=203;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=203;, score=0.576 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=203;, score=0.636 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=203;, score=0.692 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=203;, score=0.692 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=204;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=204;, score=0.576 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=204;, score=0.636 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=204;, score=0.692 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=204;, score=0.685 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=205;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=205;, score=0.576 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=205;, score=0.629 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=205;, score=0.692 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=205;, score=0.692 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=206;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=206;, score=0.576 total time=   0.5s
# [CV 3/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=206;, score=0.629 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=206;, score=0.692 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=206;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=207;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=207;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=207;, score=0.629 total time=   0.5s
# [CV 4/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=207;, score=0.685 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=207;, score=0.692 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=208;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=208;, score=0.569 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=208;, score=0.636 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=208;, score=0.692 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=208;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=209;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=209;, score=0.569 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=209;, score=0.629 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=209;, score=0.685 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=209;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.569 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.636 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.685 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=210;, score=0.685 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=211;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=211;, score=0.569 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=211;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=211;, score=0.678 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=211;, score=0.685 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=212;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=212;, score=0.569 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=212;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=212;, score=0.671 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=212;, score=0.685 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=213;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=213;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=213;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=213;, score=0.664 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=213;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=214;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=214;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=214;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=214;, score=0.671 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=214;, score=0.685 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=215;, score=0.590 total time=   0.5s
# [CV 2/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=215;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=215;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=215;, score=0.664 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=215;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=216;, score=0.590 total time=   0.5s
# [CV 2/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=216;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=216;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=216;, score=0.664 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=216;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=217;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=217;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=217;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=217;, score=0.664 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=217;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=218;, score=0.590 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=218;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=218;, score=0.629 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=218;, score=0.671 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=218;, score=0.678 total time=   0.4s
# [CV 1/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=219;, score=0.597 total time=   0.4s
# [CV 2/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=219;, score=0.562 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=219;, score=0.622 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=219;, score=0.664 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_depth=36, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=219;, score=0.678 total time=   0.4s
# GridSearchCV(estimator=RandomForestClassifier(random_state=0),
#              param_grid={'bootstrap': [False], 'max_depth': range(33, 37),
#                          'max_features': ['sqrt'], 'min_samples_leaf': [2],
#                          'min_samples_split': [4],
#                          'n_estimators': range(200, 220)},
#              verbose=3)

# %%
# Print best hyperparameters
print(grid_rfc2.best_params_)
# Out:
# {'bootstrap': False, 'max_depth': 33, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 203}

# %%
# Make predictions with the hypertuned model
grid_rfc2_train_predict = grid_rfc2.predict(X_train)
grid_rfc2_test_predict = grid_rfc2.predict(X_test)

# Calculate and print the balanced accuracies
print(f"Accuracy - Train: {balanced_accuracy_score(y_train, grid_rfc2_train_predict):.3f}")
print(f"Accuracy - Test: {balanced_accuracy_score(y_test, grid_rfc2_test_predict):.3f}")

# Calculate the classification report
print(classification_report(y_test, grid_rfc2_test_predict))
# Out:
# Accuracy - Train: 1.000
# Accuracy - Test: 0.588
#               precision    recall  f1-score   support
#
#            0       0.66      0.72      0.69        89
#            1       0.45      0.47      0.46        83
#            2       0.70      0.57      0.63        68
#
#     accuracy                           0.59       240
#    macro avg       0.60      0.59      0.59       240
# weighted avg       0.60      0.59      0.59       240

# %% [markdown]
# **Conclusion:** This model performs worse than the model built on all of the features. Not only, is the accuracy score for the test data smaller, it is also not improving the overfitting on the train data.
